# %% [markdown]
# This is our minhashing algorithm base. We test it on a small set of files and then perform a volumn test. Our main use, in the bulk minhash code file, is when we analyze all the data of a sample person

# %%
import gpxpy
import pandas as pd
import numpy as np

def get_loc_set(file_path):
    with open(file_path, 'r') as f:
        gpx = gpxpy.parse(f)

    lats = []
    longs = []
    
    for track in gpx.tracks:
        for segment in track.segments:
            # print(f"Track Name: {track.name}")
            print(f"Track Type: {track.type}") #progress update

            for point in segment.points:
                lats.append(point.latitude)
                longs.append(point.longitude)
    
    lats, longs = np.around(lats, decimals=4), np.around(longs, decimals=4)
    return set(zip(lats, longs))

#sample files to test on
filenames = ['Data/04062025_run.gpx', 'Data/04052025_run.gpx', 'Data/04072025_run.gpx', 'Data/04112025_run.gpx', 'Data/04132025_run.gpx']
coords_list = []

#run the analysis, inlcude another progress update
for i, file in enumerate(filenames):
    print(f"Analyzing file {i+1}")
    curr_coords = get_loc_set(file)
    coords_list.append(curr_coords)

#make the big set
all_coords = set()
for s in coords_list:
    all_coords = all_coords | s

#df of data D
s0 = pd.Series(list(all_coords))
result_dict = {'checker': s0}

for i, shingle_set in enumerate(coords_list):
    print(f"Processing file {i+1}: {filenames[i]}")
    column_name = filenames[i]
    
    result_dict[column_name] = s0.isin(list(shingle_set))

df = pd.DataFrame(result_dict)
df.head()
# Out:
# Analyzing file 1
# Track Type: running
# Analyzing file 2
# Track Type: running
# Analyzing file 3
# Track Type: running
# Analyzing file 4
# Track Type: running
# Analyzing file 5
# Track Type: running
# Processing file 1: Data/04062025_run.gpx
# Processing file 2: Data/04052025_run.gpx
# Processing file 3: Data/04072025_run.gpx
# Processing file 4: Data/04112025_run.gpx
# Processing file 5: Data/04132025_run.gpx
#                 checker  Data/04062025_run.gpx  Data/04052025_run.gpx  \
# 0  (39.6895, -105.1028)                   True                   True
# 1  (39.6822, -105.1119)                   True                   True
# 2  (39.6893, -105.1006)                   True                   True
# 3  (39.6827, -105.1118)                   True                   True
# 4  (39.6896, -105.0997)                   True                   True
#
#    Data/04072025_run.gpx  Data/04112025_run.gpx  Data/04132025_run.gpx
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False

# %%
import numpy as np
import pandas as pd
import hashlib

#hashing
def hash_function(seed, element):
    return int(hashlib.md5((str(seed) + str(element)).encode('utf8')).hexdigest(), 16) % 1000000

#making M
def minhash(coords_list, num_hashes=100):
    num_sets = len(coords_list)
    
    minhash_sig = np.full((num_hashes, num_sets), np.inf) #start at -infty

    for i, coord_set in enumerate(coords_list):
        for seed in range(num_hashes):
            for element in coord_set:
                hash_value = hash_function(seed, element)
                minhash_sig[seed, i] = min(minhash_sig[seed, i], hash_value) #update each entry
    
    return minhash_sig

#similarity from signature matrix
def jac_sim(minhash_sig, num_sets):
    similarities = np.zeros((num_sets, num_sets))
    
    for i in range(num_sets): #plain old jaccard similarity
        for j in range(i, num_sets):
            matching_hashes = np.sum(minhash_sig[:, i] == minhash_sig[:, j])
            sim = matching_hashes / minhash_sig.shape[0]
            similarities[i, j] = sim
            similarities[j, i] = sim #setting both just for visibility and lining up
    
    return similarities

num_sets = len(coords_list)

minhash_sig = minhash(coords_list, 100)
similarities = jac_sim(minhash_sig, num_sets)
print(similarities) #should see results
# Out:
# [[1.   0.71 0.   0.   0.  ]
#  [0.71 1.   0.   0.   0.  ]
#  [0.   0.   1.   0.67 0.62]
#  [0.   0.   0.67 1.   0.61]
#  [0.   0.   0.62 0.61 1.  ]]

# %% [markdown]
# This is the volume test, which we did to make sure this was usable with the amount of data

# %%
activities = pd.read_csv('Data/activities.csv', delimiter = ',')
files = activities['Filename'].tolist()[:-1]
filenames = [] 

#a bit annoying to get out the files, just use these
for f in files:
    if not isinstance(f, float): #some values aren't numeric, some have nan issues
        if f[-3:] == 'gpx':
            filenames.append(f)
print(filenames)
for i, file in enumerate(filenames[1::]):
    s = 'Data/' + file
    # print(i)
    curr_coords = get_loc_set(s)
    coords_list.append(curr_coords)

#same as before
all_coords = set()
for s in coords_list:
    all_coords = all_coords | s

s0 = pd.Series(list(all_coords))
result_dict = {'checker': s0}

for i, shingle_set in enumerate(coords_list):
    if (i < 87): #general cutoff to make sure it doesn't take too long, can modify
        print(f"Processing file {i+1}: {filenames[i]}")
        column_name = filenames[i]
        
        result_dict[column_name] = s0.isin(list(shingle_set))

df = pd.DataFrame(result_dict)
df.head()
# Out:
# ['activities/7664030898.gpx', 'activities/9201531314.gpx', 'activities/9208399131.gpx', 'activities/10195845861.gpx', 'activities/10213672242.gpx', 'activities/10236119203.gpx', 'activities/10297798873.gpx', 'activities/10306102382.gpx', 'activities/10328738170.gpx', 'activities/10339669514.gpx', 'activities/10359765824.gpx', 'activities/10368538574.gpx', 'activities/10380623110.gpx', 'activities/10426958756.gpx', 'activities/10470627375.gpx', 'activities/10608835232.gpx', 'activities/10676173524.gpx', 'activities/10722751798.gpx', 'activities/10755668518.gpx', 'activities/10790430718.gpx', 'activities/10796100865.gpx', 'activities/10821874440.gpx', 'activities/10842702052.gpx', 'activities/10862944105.gpx', 'activities/10938133614.gpx', 'activities/10994695872.gpx', 'activities/11017203672.gpx', 'activities/11031595610.gpx', 'activities/11047818855.gpx', 'activities/11062019984.gpx', 'activities/11070852384.gpx', 'activities/11092450380.gpx', 'activities/11143843698.gpx', 'activities/11190344963.gpx', 'activities/11240578760.gpx', 'activities/11249157742.gpx', 'activities/11249531055.gpx', 'activities/11300365890.gpx', 'activities/11324217227.gpx', 'activities/11345707677.gpx', 'activities/11349393304.gpx', 'activities/11380285324.gpx', 'activities/11380364570.gpx', 'activities/11388713503.gpx', 'activities/11463000833.gpx', 'activities/11473543729.gpx', 'activities/11525185682.gpx', 'activities/11584396426.gpx', 'activities/11647493469.gpx', 'activities/11653541961.gpx', 'activities/11692709977.gpx', 'activities/11723859881.gpx', 'activities/11726997676.gpx', 'activities/11735274471.gpx', 'activities/11751649553.gpx', 'activities/11790536827.gpx', 'activities/11906755294.gpx', 'activities/12107359382.gpx', 'activities/12183792449.gpx', 'activities/12216109661.gpx', 'activities/12254910873.gpx', 'activities/12272923134.gpx', 'activities/12374830499.gpx', 'activities/12382925598.gpx', 'activities/12467838018.gpx', 'activities/12496996788.gpx', 'activities/12583526389.gpx', 'activities/12585663289.gpx', 'activities/12625061734.gpx', 'activities/12625968963.gpx', 'activities/12632680780.gpx', 'activities/12648726677.gpx', 'activities/12758777202.gpx', 'activities/12761920012.gpx', 'activities/12815103827.gpx', 'activities/12872120440.gpx', 'activities/12900677054.gpx', 'activities/12948155220.gpx', 'activities/13027178753.gpx', 'activities/13041585169.gpx', 'activities/13073839675.gpx', 'activities/13131191690.gpx', 'activities/13164669518.gpx', 'activities/13249523361.gpx', 'activities/13293241181.gpx', 'activities/13344307734.gpx', 'activities/13502255084.gpx']
# Track Type: cycling
# Track Type: cycling
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: cycling
# Track Type: running
# Track Type: cycling
# Track Type: cycling
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: cycling
# Track Type: cycling
# Track Type: running
# Track Type: running
# Track Type: cycling
# Track Type: cycling
# Track Type: cycling
# Track Type: running
# Track Type: cycling
# Track Type: cycling
# Track Type: cycling
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: cycling
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: cycling
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: cycling
# Track Type: running
# Track Type: cycling
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: running
# Track Type: NordicSki
# Track Type: running
# Track Type: running
# Processing file 1: activities/7664030898.gpx
# Processing file 2: activities/9201531314.gpx
# Processing file 3: activities/9208399131.gpx
# Processing file 4: activities/10195845861.gpx
# Processing file 5: activities/10213672242.gpx
# Processing file 6: activities/10236119203.gpx
# Processing file 7: activities/10297798873.gpx
# Processing file 8: activities/10306102382.gpx
# Processing file 9: activities/10328738170.gpx
# Processing file 10: activities/10339669514.gpx
# Processing file 11: activities/10359765824.gpx
# Processing file 12: activities/10368538574.gpx
# Processing file 13: activities/10380623110.gpx
# Processing file 14: activities/10426958756.gpx
# Processing file 15: activities/10470627375.gpx
# Processing file 16: activities/10608835232.gpx
# Processing file 17: activities/10676173524.gpx
# Processing file 18: activities/10722751798.gpx
# Processing file 19: activities/10755668518.gpx
# Processing file 20: activities/10790430718.gpx
# Processing file 21: activities/10796100865.gpx
# Processing file 22: activities/10821874440.gpx
# Processing file 23: activities/10842702052.gpx
# Processing file 24: activities/10862944105.gpx
# Processing file 25: activities/10938133614.gpx
# Processing file 26: activities/10994695872.gpx
# Processing file 27: activities/11017203672.gpx
# Processing file 28: activities/11031595610.gpx
# Processing file 29: activities/11047818855.gpx
# Processing file 30: activities/11062019984.gpx
# Processing file 31: activities/11070852384.gpx
# Processing file 32: activities/11092450380.gpx
# Processing file 33: activities/11143843698.gpx
# Processing file 34: activities/11190344963.gpx
# Processing file 35: activities/11240578760.gpx
# Processing file 36: activities/11249157742.gpx
# Processing file 37: activities/11249531055.gpx
# Processing file 38: activities/11300365890.gpx
# Processing file 39: activities/11324217227.gpx
# Processing file 40: activities/11345707677.gpx
# Processing file 41: activities/11349393304.gpx
# Processing file 42: activities/11380285324.gpx
# Processing file 43: activities/11380364570.gpx
# Processing file 44: activities/11388713503.gpx
# Processing file 45: activities/11463000833.gpx
# Processing file 46: activities/11473543729.gpx
# Processing file 47: activities/11525185682.gpx
# Processing file 48: activities/11584396426.gpx
# Processing file 49: activities/11647493469.gpx
# Processing file 50: activities/11653541961.gpx
# Processing file 51: activities/11692709977.gpx
# Processing file 52: activities/11723859881.gpx
# Processing file 53: activities/11726997676.gpx
# Processing file 54: activities/11735274471.gpx
# Processing file 55: activities/11751649553.gpx
# Processing file 56: activities/11790536827.gpx
# Processing file 57: activities/11906755294.gpx
# Processing file 58: activities/12107359382.gpx
# Processing file 59: activities/12183792449.gpx
# Processing file 60: activities/12216109661.gpx
# Processing file 61: activities/12254910873.gpx
# Processing file 62: activities/12272923134.gpx
# Processing file 63: activities/12374830499.gpx
# Processing file 64: activities/12382925598.gpx
# Processing file 65: activities/12467838018.gpx
# Processing file 66: activities/12496996788.gpx
# Processing file 67: activities/12583526389.gpx
# Processing file 68: activities/12585663289.gpx
# Processing file 69: activities/12625061734.gpx
# Processing file 70: activities/12625968963.gpx
# Processing file 71: activities/12632680780.gpx
# Processing file 72: activities/12648726677.gpx
# Processing file 73: activities/12758777202.gpx
# Processing file 74: activities/12761920012.gpx
# Processing file 75: activities/12815103827.gpx
# Processing file 76: activities/12872120440.gpx
# Processing file 77: activities/12900677054.gpx
# Processing file 78: activities/12948155220.gpx
# Processing file 79: activities/13027178753.gpx
# Processing file 80: activities/13041585169.gpx
# Processing file 81: activities/13073839675.gpx
# Processing file 82: activities/13131191690.gpx
# Processing file 83: activities/13164669518.gpx
# Processing file 84: activities/13249523361.gpx
# Processing file 85: activities/13293241181.gpx
# Processing file 86: activities/13344307734.gpx
# Processing file 87: activities/13502255084.gpx
#                 checker  activities/7664030898.gpx  activities/9201531314.gpx  \
# 0  (39.5821, -105.0321)                      False                      False
# 1   (36.3302, -94.1021)                      False                      False
# 2   (39.983, -105.2426)                      False                      False
# 3  (39.7477, -105.2191)                      False                      False
# 4  (39.6847, -105.0402)                      False                      False
#
#    activities/9208399131.gpx  activities/10195845861.gpx  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
#
#    activities/10213672242.gpx  activities/10236119203.gpx  \
# 0                       False                       False
# 1                       False                        True
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    activities/10297798873.gpx  activities/10306102382.gpx  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    activities/10328738170.gpx  ...  activities/12948155220.gpx  \
# 0                       False  ...                       False
# 1                       False  ...                       False
# 2                       False  ...                       False
# 3                       False  ...                       False
# 4                       False  ...                       False
#
#    activities/13027178753.gpx  activities/13041585169.gpx  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    activities/13073839675.gpx  activities/13131191690.gpx  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    activities/13164669518.gpx  activities/13249523361.gpx  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    activities/13293241181.gpx  activities/13344307734.gpx  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    activities/13502255084.gpx
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
# [5 rows x 88 columns]
